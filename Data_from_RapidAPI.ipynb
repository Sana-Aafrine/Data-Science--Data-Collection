# %% [markdown]
# # Working with API

# %%
import pandas as pd
import requests

url = "https://covid-193.p.rapidapi.com/statistics"

headers = {
	"x-rapidapi-key": "9e4ed3f522msh3e6df852013819ep1c63ccjsn55e40ec389ee",
	"x-rapidapi-host": "covid-193.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

response_df=pd.DataFrame(response.json()['response'])

# %%
df=response_df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   continent   236 non-null    object
#  1   country     238 non-null    object
#  2   population  229 non-null    float64
#  3   cases       238 non-null    object
#  4   deaths      238 non-null    object
#  5   tests       238 non-null    object
#  6   day         238 non-null    object
#  7   time        238 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 15.0+ KB

# %%
df['tests'][27]
# Out:
# {'1M_pop': '10988', 'total': 191341}

# %%
total=[]
death=[]
tests=[]
recovered=[]
for i,j in df.iterrows():
    total.append(j['cases']['total'])
    death.append(j['deaths']['total'])
    recovered.append(j['cases']['recovered'])
    tests.append(j['tests']['total'])
    
df['Cases'] = total
df['Recovered'] = recovered
df['Deaths'] = death
df['Tests'] = tests

# %%
df=df.set_index('country')

# %%
df=df.drop(columns=['cases','tests','deaths'])

# %%
df.to_csv('covid_19.csv')

# %%
df
# Out:
#                       continent   population         day  \
# country
# Saint-Helena             Africa       6115.0  2024-06-30
# Falkland-Islands  South-America       3539.0  2024-06-30
# Montserrat        North-America       4965.0  2024-06-30
# Diamond-Princess           None          NaN  2024-06-30
# Vatican-City             Europe        799.0  2024-06-30
# ...                         ...          ...         ...
# Argentina         South-America   46010234.0  2024-06-30
# Netherlands              Europe   17211447.0  2024-06-30
# Mexico            North-America  131562772.0  2024-06-30
# Iran                       Asia   86022837.0  2024-06-30
# Indonesia                  Asia  279134505.0  2024-06-30
#
#                                        time     Cases  Recovered    Deaths  \
# country
# Saint-Helena      2024-06-30T16:15:16+00:00      2166        2.0       NaN
# Falkland-Islands  2024-06-30T16:15:16+00:00      1930     1930.0       NaN
# ...
